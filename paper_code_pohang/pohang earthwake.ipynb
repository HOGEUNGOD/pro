# %%
import numpy as np
import pandas as pd
import cv2


def mouse_callback(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        points.append([x,np.shape(img)[0]-y])
        print("마우스 이벤트발생, x:", x, "y:", np.shape(img)[0]-y, "클릭 :",len(points))


img = cv2.imread('graph.png')
aa = np.shape(img)
print(aa[0])

cv2.namedWindow('image')
cv2.setMouseCallback('image', mouse_callback)

points = []
x=[]
y=[]
number = []
num=0

while(True):

    cv2.imshow('image', img)

    k=cv2.waitKey(1)&0xFF
    if k == 27:
        for i in points:
            num += 1
            number = np.append(number, num)
            x = np.append(x, i[0])
            y = np.append(y, i[1])


        break


data_union = {'Contour N.o.': number,'x' :x ,'y': y}
df = pd.DataFrame(data_union)
df.to_excel('back.xlsx')
cv2.destroyAllWindows()
# Out:
# 938
# 마우스 이벤트발생, x: 95 y: 332 클릭 : 1
# 마우스 이벤트발생, x: 269 y: 369 클릭 : 2
# 마우스 이벤트발생, x: 266 y: 319 클릭 : 3
# 마우스 이벤트발생, x: 264 y: 318 클릭 : 4
# 마우스 이벤트발생, x: 269 y: 312 클릭 : 5
# 마우스 이벤트발생, x: 260 y: 300 클릭 : 6
# 마우스 이벤트발생, x: 293 y: 314 클릭 : 7
# 마우스 이벤트발생, x: 296 y: 310 클릭 : 8
# 마우스 이벤트발생, x: 353 y: 325 클릭 : 9
# 마우스 이벤트발생, x: 270 y: 230 클릭 : 10
# 마우스 이벤트발생, x: 256 y: 209 클릭 : 11
# 마우스 이벤트발생, x: 292 y: 211 클릭 : 12
# 마우스 이벤트발생, x: 259 y: 181 클릭 : 13
# 마우스 이벤트발생, x: 296 y: 152 클릭 : 14
# 마우스 이벤트발생, x: 393 y: 227 클릭 : 15
# 마우스 이벤트발생, x: 761 y: 326 클릭 : 16
# 마우스 이벤트발생, x: 1084 y: 488 클릭 : 17
# 마우스 이벤트발생, x: 1068 y: 447 클릭 : 18
# 마우스 이벤트발생, x: 1062 y: 379 클릭 : 19
# 마우스 이벤트발생, x: 1083 y: 342 클릭 : 20
# 마우스 이벤트발생, x: 1078 y: 344 클릭 : 21
# 마우스 이벤트발생, x: 1064 y: 344 클릭 : 22
# 마우스 이벤트발생, x: 1057 y: 344 클릭 : 23
# 마우스 이벤트발생, x: 1056 y: 331 클릭 : 24
# 마우스 이벤트발생, x: 1066 y: 327 클릭 : 25
# 마우스 이벤트발생, x: 1062 y: 318 클릭 : 26
# 마우스 이벤트발생, x: 1072 y: 312 클릭 : 27
# 마우스 이벤트발생, x: 1058 y: 303 클릭 : 28
# ...

# %%
import matplotlib.pyplot as plt
print(df)

# df.plot.scatter('x','y')
magnitude = np.array(df)
x = magnitude[:,1]*8/2001
y=  magnitude[:,2]*8/938-2


plt.scatter(x,y,  facecolors ='none', edgecolors='r')
plt.ylim(-2,6)
plt.xlim(0,8)
plt.grid()
# Out:
#     Contour N.o.       x      y
# 0            1.0    95.0  332.0
# 1            2.0   269.0  369.0
# 2            3.0   266.0  319.0
# 3            4.0   264.0  318.0
# 4            5.0   269.0  312.0
# ..           ...     ...    ...
# 83          84.0  1886.0  570.0
# 84          85.0  1886.0  485.0
# 85          86.0  1885.0  436.0
# 86          87.0  1886.0  423.0
# 87          88.0  1884.0  383.0
#
# [88 rows x 3 columns]

# %%
import cv2
import numpy as np
import pandas as pd
import cv2


def mouse_callback(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        points.append([x,np.shape(img)[0]-y])
        print("마우스 이벤트발생, x:", x, "y:", np.shape(img)[0]-y, "클릭 :",len(points))


img = cv2.imread('graph.png')
aa = np.shape(img)
print(aa[0])

cv2.namedWindow('image')
cv2.setMouseCallback('image', mouse_callback)

points = []
x=[]
y=[]
number = []
num=0

while(True):

    cv2.imshow('image', img)

    k=cv2.waitKey(1)&0xFF
    if k == 27:
        for i in points:
            num += 1
            number = np.append(number, num)
            x = np.append(x, i[0])
            y = np.append(y, i[1])


        break


data_union = {'Contour N.o.': number,'x' :x ,'y': y}
df = pd.DataFrame(data_union)
df.to_excel('net injection.xlsx')
cv2.destroyAllWindows()
# Out:
# 938
# 마우스 이벤트발생, x: 245 y: 4 클릭 : 1
# 마우스 이벤트발생, x: 248 y: 24 클릭 : 2
# 마우스 이벤트발생, x: 252 y: 53 클릭 : 3
# 마우스 이벤트발생, x: 251 y: 66 클릭 : 4
# 마우스 이벤트발생, x: 254 y: 85 클릭 : 5
# 마우스 이벤트발생, x: 260 y: 111 클릭 : 6
# 마우스 이벤트발생, x: 262 y: 121 클릭 : 7
# 마우스 이벤트발생, x: 274 y: 122 클릭 : 8
# 마우스 이벤트발생, x: 280 y: 142 클릭 : 9
# 마우스 이벤트발생, x: 283 y: 160 클릭 : 10
# 마우스 이벤트발생, x: 284 y: 167 클릭 : 11
# 마우스 이벤트발생, x: 289 y: 172 클릭 : 12
# 마우스 이벤트발생, x: 290 y: 178 클릭 : 13
# 마우스 이벤트발생, x: 294 y: 186 클릭 : 14
# 마우스 이벤트발생, x: 329 y: 185 클릭 : 15
# 마우스 이벤트발생, x: 333 y: 181 클릭 : 16
# 마우스 이벤트발생, x: 332 y: 178 클릭 : 17
# 마우스 이벤트발생, x: 336 y: 178 클릭 : 18
# 마우스 이벤트발생, x: 343 y: 172 클릭 : 19
# 마우스 이벤트발생, x: 355 y: 167 클릭 : 20
# 마우스 이벤트발생, x: 368 y: 163 클릭 : 21
# 마우스 이벤트발생, x: 378 y: 160 클릭 : 22
# 마우스 이벤트발생, x: 392 y: 156 클릭 : 23
# 마우스 이벤트발생, x: 405 y: 153 클릭 : 24
# 마우스 이벤트발생, x: 415 y: 150 클릭 : 25
# 마우스 이벤트발생, x: 426 y: 147 클릭 : 26
# 마우스 이벤트발생, x: 448 y: 143 클릭 : 27
# 마우스 이벤트발생, x: 458 y: 141 클릭 : 28
# ...

# %%
import cv2
import numpy as np
import pandas as pd
import cv2


def mouse_callback(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        points.append([x,np.shape(img)[0]-y])
        print("마우스 이벤트발생, x:", x, "y:", np.shape(img)[0]-y, "클릭 :",len(points))


img = cv2.imread('graph.png')
aa = np.shape(img)
print(aa[0])

cv2.namedWindow('image')
cv2.setMouseCallback('image', mouse_callback)

points = []
x=[]
y=[]
number = []
num=0

while(True):

    cv2.imshow('image', img)

    k=cv2.waitKey(1)&0xFF
    if k == 27:
        for i in points:
            num += 1
            number = np.append(number, num)
            x = np.append(x, i[0])
            y = np.append(y, i[1])


        break


data_union = {'Contour N.o.': number,'x' :x ,'y': y}
df = pd.DataFrame(data_union)
df.to_excel('injection.xlsx')
cv2.destroyAllWindows()
# Out:
# 938
# 마우스 이벤트발생, x: 246 y: 25 클릭 : 1
# 마우스 이벤트발생, x: 253 y: 330 클릭 : 2
# 마우스 이벤트발생, x: 260 y: 101 클릭 : 3
# 마우스 이벤트발생, x: 262 y: 95 클릭 : 4
# 마우스 이벤트발생, x: 265 y: 3 클릭 : 5
# 마우스 이벤트발생, x: 276 y: 2 클릭 : 6
# 마우스 이벤트발생, x: 278 y: 95 클릭 : 7
# 마우스 이벤트발생, x: 280 y: 105 클릭 : 8
# 마우스 이벤트발생, x: 283 y: 112 클릭 : 9
# 마우스 이벤트발생, x: 286 y: 157 클릭 : 10
# 마우스 이벤트발생, x: 288 y: 45 클릭 : 11
# 마우스 이벤트발생, x: 292 y: 76 클릭 : 12
# 마우스 이벤트발생, x: 295 y: 3 클릭 : 13
# 마우스 이벤트발생, x: 1046 y: 4 클릭 : 14
# 마우스 이벤트발생, x: 1057 y: 826 클릭 : 15
# 마우스 이벤트발생, x: 1060 y: 479 클릭 : 16
# 마우스 이벤트발생, x: 1062 y: 469 클릭 : 17
# 마우스 이벤트발생, x: 1071 y: 5 클릭 : 18
# 마우스 이벤트발생, x: 1076 y: 3 클릭 : 19
# 마우스 이벤트발생, x: 1078 y: 72 클릭 : 20
# 마우스 이벤트발생, x: 1083 y: 3 클릭 : 21
# 마우스 이벤트발생, x: 1273 y: 3 클릭 : 22
# 마우스 이벤트발생, x: 1280 y: 15 클릭 : 23
# 마우스 이벤트발생, x: 1284 y: 3 클릭 : 24
# 마우스 이벤트발생, x: 1295 y: 6 클릭 : 25
# 마우스 이벤트발생, x: 1297 y: 49 클릭 : 26
# 마우스 이벤트발생, x: 1301 y: 51 클릭 : 27
# 마우스 이벤트발생, x: 1306 y: 53 클릭 : 28
# 마우스 이벤트발생, x: 1313 y: 195 클릭 : 29
# ...

# %%
import matplotlib.pyplot as plt
print(df)

# df.plot.scatter('x','y')
net_injction = np.array(df)
x = net_injction[:,1]*8/2001
y=  net_injction[:,2]*1000/938-2


plt.plot(x,y)
plt.ylim(0,1000)
plt.xlim(0,8)
plt.grid()
# Out:
#     Contour N.o.       x      y
# 0            1.0   246.0   25.0
# 1            2.0   253.0  330.0
# 2            3.0   260.0  101.0
# 3            4.0   262.0   95.0
# 4            5.0   265.0    3.0
# ..           ...     ...    ...
# 58          59.0  1737.0    6.0
# 59          60.0  1743.0    6.0
# 60          61.0  1741.0  167.0
# 61          62.0  1744.0    3.0
# 62          63.0  1887.0    3.0
#
# [63 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
print(df)

# df.plot.scatter('x','y')
net_injction = np.array(df)
x = net_injction[:,1]*8/2001
y=  net_injction[:,2]*1000/938


plt.plot(x,y)
plt.ylim(0,1000)
plt.xlim(0,8)
plt.grid()
# Out:
#      Contour N.o.       x      y
# 0             1.0   245.0    4.0
# 1             2.0   248.0   24.0
# 2             3.0   252.0   53.0
# 3             4.0   251.0   66.0
# 4             5.0   254.0   85.0
# ..            ...     ...    ...
# 150         151.0  1808.0  579.0
# 151         152.0  1825.0  573.0
# 152         153.0  1840.0  566.0
# 153         154.0  1856.0  560.0
# 154         155.0  1885.0  550.0
#
# [155 rows x 3 columns]

# %%
import cv2
import numpy as np
import pandas as pd
import cv2


def mouse_callback(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        points.append([x,np.shape(img)[0]-y])
        print("마우스 이벤트발생, x:", x, "y:", np.shape(img)[0]-y, "클릭 :",len(points))


img = cv2.imread('graph.png')
aa = np.shape(img)
print(aa[0])

cv2.namedWindow('image')
cv2.setMouseCallback('image', mouse_callback)

points = []
x=[]
y=[]
number = []
num=0

while(True):

    cv2.imshow('image', img)

    k=cv2.waitKey(1)&0xFF
    if k == 27:
        for i in points:
            num += 1
            number = np.append(number, num)
            x = np.append(x, i[0])
            y = np.append(y, i[1])


        break


data_union = {'Contour N.o.': number,'x' :x ,'y': y}

df = pd.DataFrame(data_union)
df.to_excel('back flow.xlsx')
cv2.destroyAllWindows()
# Out:
# 938
# 마우스 이벤트발생, x: 248 y: 2 클릭 : 1
# 마우스 이벤트발생, x: 329 y: 2 클릭 : 2
# 마우스 이벤트발생, x: 333 y: 85 클릭 : 3
# 마우스 이벤트발생, x: 336 y: 10 클릭 : 4
# 마우스 이벤트발생, x: 341 y: 19 클릭 : 5
# 마우스 이벤트발생, x: 346 y: 9 클릭 : 6
# 마우스 이벤트발생, x: 355 y: 9 클릭 : 7
# 마우스 이벤트발생, x: 362 y: 13 클릭 : 8
# 마우스 이벤트발생, x: 367 y: 10 클릭 : 9
# 마우스 이벤트발생, x: 375 y: 7 클릭 : 10
# 마우스 이벤트발생, x: 382 y: 4 클릭 : 11
# 마우스 이벤트발생, x: 390 y: 9 클릭 : 12
# 마우스 이벤트발생, x: 427 y: 7 클릭 : 13
# 마우스 이벤트발생, x: 443 y: 4 클릭 : 14
# 마우스 이벤트발생, x: 665 y: 2 클릭 : 15
# 마우스 이벤트발생, x: 965 y: 1 클릭 : 16
# 마우스 이벤트발생, x: 968 y: 5 클릭 : 17
# 마우스 이벤트발생, x: 1064 y: 4 클릭 : 18
# 마우스 이벤트발생, x: 1069 y: 316 클릭 : 19
# 마우스 이벤트발생, x: 1072 y: 24 클릭 : 20
# 마우스 이벤트발생, x: 1075 y: 29 클릭 : 21
# 마우스 이벤트발생, x: 1077 y: 6 클릭 : 22
# 마우스 이벤트발생, x: 1085 y: 266 클릭 : 23
# 마우스 이벤트발생, x: 1089 y: 78 클릭 : 24
# 마우스 이벤트발생, x: 1091 y: 98 클릭 : 25
# 마우스 이벤트발생, x: 1097 y: 51 클릭 : 26
# 마우스 이벤트발생, x: 1102 y: 81 클릭 : 27
# 마우스 이벤트발생, x: 1105 y: 14 클릭 : 28
# 마우스 이벤트발생, x: 1106 y: 4 클릭 : 29
# ...

# %%
import matplotlib.pyplot as plt
print(df)

# df.plot.scatter('x','y')
back_flow = np.array(df)
x = back_flow[:,1]*8/2001
y=  back_flow[:,2]*1000/938


plt.plot(x,y)
plt.ylim(0,1000)
plt.xlim(0,8)
plt.grid()
# Out:
#      Contour N.o.       x     y
# 0             1.0   248.0   2.0
# 1             2.0   329.0   2.0
# 2             3.0   333.0  85.0
# 3             4.0   336.0  10.0
# 4             5.0   341.0  19.0
# ..            ...     ...   ...
# 113         114.0  1838.0  12.0
# 114         115.0  1840.0  14.0
# 115         116.0  1846.0   9.0
# 116         117.0  1859.0  11.0
# 117         118.0  1882.0  11.0
#
# [118 rows x 3 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.font_manager import FontProperties

magnitude_excel = np.array(pd.read_excel('magnitude.xlsx'))
magnitude_x = magnitude_excel[:,2]*8/2001
magnitude_y = magnitude_excel[:,3]*8/938-2

net_injection = np.array(pd.read_excel('net injection.xlsx'))
net_injection_x = net_injection[:,2]*8/2001
net_injection_y=  net_injection[:,3]*1000/938

injection = np.array(pd.read_excel('injection.xlsx'))
injection_x = injection[:,2]*8/2001
injection_y=  injection[:,3]*1000/938

back_flow = np.array(pd.read_excel('back flow.xlsx'))
back_flow_x = back_flow[:,2]*8/2001
back_flow_y=  back_flow[:,3]*1000/938


fig, ax1 = plt.subplots(figsize=[10, 5])
ax = ax1.twinx()

ax.scatter(magnitude_x, magnitude_y, linewidths=2.5,facecolors ='none', edgecolors='r',label='Magnitude',zorder=1)

ax.set_ylim(-2,6)
ax.set_xlim(0,8)

ax1.plot(injection_x, injection_y, c='blue' , label='Injection',linewidth='2.5', zorder=1)
ax.plot([-1],[-1],c= 'blue', label='Injection')
ax1.plot(net_injection_x, net_injection_y,c= 'black', label='Net injection',linewidth='2.5', zorder=2)
ax.plot([-1],[-1],c= 'black', label='Net injection')
ax1.plot(back_flow_x, back_flow_y,c= 'gold', label='Net injection',linewidth='2.5', zorder=2)
ax.plot([-1],[-1],c= 'gold', label='Flow back')


ax1.set_ylim(0,1000)
labels = [item.get_text() for item in ax.get_xticklabels()]
labels[0]= '23 Oct 2015'
labels[1]= '31 Jan 2016'
labels[2]= '10 May 2016'
labels[3]= '18 Aug 2016'
labels[4]= '26 Nov 2016'
labels[5]= '06 Mar 2017'
labels[6]= '14 Jun 2017'
labels[7]= '22 Sep 2017'
labels[8]= '31 Dec 2017'

ax.legend()
ax.set_ylabel('Magnitude '+r'( $M_{L}$ )')
ax1.set_ylabel('Injection volume' + r'( $ m^{3}/day $ )' +'\n'+ 'Net cumulative injection volume' + r'( $ \times10m^{3} $ )')


font = FontProperties()
# font.set_family('serif')
# font.set_name('Times New Roman')
# font.set_style('italic')
ax.tick_params(direction='in')
ax1.tick_params(direction='in')
ax1.set_xticklabels(labels,fontsize=9, ha="center")
ax1.tick_params(axis='x', pad=10, length=5)
ax1.grid(axis='y')
ax1.tick_params(zorder=10)
ax.set_axisbelow(True)
ax1.set_axisbelow(True)
# ax1.xaxis.tick_bottom()
ax1.text(0.75,440,'Stage 1\n  PX-2')
ax1.text(3.95,900,'Stage 2\n  PX-1')
ax1.text(5.1, 690, 'Stage 3\n  PX-2')
ax1.text(6.100, 700, 'Stage 4\n  PX-1')
ax1.text(7.006, 695, 'Stage 5\n  PX-2')

SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 14

plt.rc('font', size=BIGGER_SIZE) # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE) # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE) # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE) # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE) # fontsize of the tick labels
plt.rc('legend', fontsize=BIGGER_SIZE) # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE) # fontsize of the figure title

ax1.patch.set_visible(False)


plt.savefig('./abc.jpeg', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-77a1a739a79e> in <module>
#       4 from matplotlib.font_manager import FontProperties
#       5
# ----> 6 magnitude_excel = np.array(pd.read_excel('magnitude.xlsx'))
#       7 magnitude_x = magnitude_excel[:,2]*8/2001
#       8 magnitude_y = magnitude_excel[:,3]*8/938-2
#
# ~\Anaconda3\envs\pro\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
plt.savefig()
